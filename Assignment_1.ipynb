# %%
# STEP 1: Import Required Libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = "Cats are running faster than dogs and playing happily."

# STEP 2: Preprocess Text
text = text.lower()

# STEP 3: Tokenization
tokens = word_tokenize(text)

# STEP 4: Stemming
ps = PorterStemmer()
stemmed_words = []

for word in tokens:
    stemmed_words.append(ps.stem(word))

# STEP 5: Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = []

for word in tokens:
    lemmatized_words.append(lemmatizer.lemmatize(word))


print("Original Tokens:", tokens)
print("Stemmed Words:", stemmed_words)
print("Lemmatized Words:", lemmatized_words)
# Out:
# Original Tokens: ['cats', 'are', 'running', 'faster', 'than', 'dogs', 'and', 'playing', 'happily', '.']
# Stemmed Words: ['cat', 'are', 'run', 'faster', 'than', 'dog', 'and', 'play', 'happili', '.']
# Lemmatized Words: ['cat', 'are', 'running', 'faster', 'than', 'dog', 'and', 'playing', 'happily', '.']
